# %%
from mlflow.tracking import MlflowClient

MLFLOW_TRACKING_URI = "sqlite:///new.db"

client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
import pandas as pd
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso 

from sklearn.metrics import root_mean_squared_error

# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///new.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# 2024/06/09 19:53:20 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/kamilakolpashnikova/Dropbox/Mac/Documents/Jupyter_notebooks/mlops-2024/02-experiment-tracking/mlruns/1', creation_time=1717977200591, experiment_id='1', last_update_time=1717977200591, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)
    df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
    df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
    
    df['duration'] = df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']

    df['duration'] = df['duration'].dt.total_seconds() / 60
    
    df = df[(df.duration>=1) & (df.duration <= 60)]
    
    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('data/yellow_tripdata_2023-01.parquet')
df_val = read_dataframe('data/yellow_tripdata_2023-02.parquet')
df_val.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-02-01 00:32:53   2023-02-01 00:34:34              2.0
# 3         1  2023-02-01 00:29:33   2023-02-01 01:01:38              0.0
# 4         2  2023-02-01 00:12:28   2023-02-01 00:25:46              1.0
# 5         1  2023-02-01 00:52:40   2023-02-01 01:07:18              1.0
# 6         1  2023-02-01 00:12:39   2023-02-01 00:40:36              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag PULocationID DOLocationID  \
# 0           0.30         1.0                  N          142          163
# 3          18.80         1.0                  N          132           26
# 4           3.22         1.0                  N          161          145
# 5           5.10         1.0                  N          148          236
# 6           8.90         1.0                  N          137          244
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          4.4   3.50      0.5        0.00           0.0
# 3             1         70.9   2.25      0.5        0.00           0.0
# 4             1         17.0   1.00      0.5        3.30           0.0
# 5             1         21.9   3.50      0.5        5.35           0.0
# 6             1         41.5   3.50      0.5        3.50           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 0                    1.0          9.40                   2.5         0.00
# 3                    1.0         74.65                   0.0         1.25
# 4                    1.0         25.30                   2.5         0.00
# 5                    1.0         32.25                   2.5         0.00
# 6                    1.0         50.00                   2.5         0.00
#
#     duration
# 0   1.683333
# 3  32.083333
# 4  13.300000
# 5  14.633333
# 6  27.950000

# %%
train_dict = df_train[['PULocationID', 'DOLocationID']].to_dict(orient='records')
val_dict = df_val[['PULocationID', 'DOLocationID']].to_dict(orient='records')

# %%
# Create the DictVectorizer
dv = DictVectorizer()

# Fit and transform the data
X_train = dv.fit_transform(train_dict)
X_val = dv.transform(val_dict)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
alpha = 0.01

lr = Lasso(alpha)
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
# Out:
# 8.138118733385994

# %%
with mlflow.start_run():
    mlflow.set_tag("developer","Qfl3x")
    
    mlflow.log_param("train-data-path", "data/green_tripdata_2021-01.parquet")
    mlflow.log_param("val-data-path", "data/green_tripdata_2021-02.parquet")
    
    alpha = 0.01
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)
    
    y_pred = lr.predict(X_val)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=100, # was 1000 in the original code
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [19:06:33] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:7.85020
# [1]	validation-rmse:7.33480
# [2]	validation-rmse:6.71042
# [3]	validation-rmse:6.58682
# [4]	validation-rmse:6.50465
# [5]	validation-rmse:6.41720
# [6]	validation-rmse:6.15263
# [7]	validation-rmse:6.08645
# [8]	validation-rmse:6.03566
# [9]	validation-rmse:5.97975
# [10]	validation-rmse:5.90972
# [11]	validation-rmse:5.78353
# [12]	validation-rmse:5.76575
# [13]	validation-rmse:5.72657
# [14]	validation-rmse:5.65600
# [15]	validation-rmse:5.56602
# [16]	validation-rmse:5.55760
# [17]	validation-rmse:5.51289
# [18]	validation-rmse:5.50613
# [19]	validation-rmse:5.49697
# [20]	validation-rmse:5.46254
# [21]	validation-rmse:5.45078
# [22]	validation-rmse:5.43478
# [23]	validation-rmse:5.42656
# [24]	validation-rmse:5.42197
# [25]	validation-rmse:5.38385
# [26]	validation-rmse:5.36458
# [27]	validation-rmse:5.35596
# [28]	validation-rmse:5.34521
# [29]	validation-rmse:5.33303
# [30]	validation-rmse:5.32312
# [31]	validation-rmse:5.32203
# [32]	validation-rmse:5.30309
# [33]	validation-rmse:5.29196
# [34]	validation-rmse:5.28989
# [35]	validation-rmse:5.28868
# [36]	validation-rmse:5.28354
# [37]	validation-rmse:5.27439
# [38]	validation-rmse:5.26249
# [39]	validation-rmse:5.25681
# [40]	validation-rmse:5.25539
# [41]	validation-rmse:5.25328
# [42]	validation-rmse:5.25225
# [43]	validation-rmse:5.24816
# [44]	validation-rmse:5.24692
# [45]	validation-rmse:5.24285
# [46]	validation-rmse:5.24007
# [47]	validation-rmse:5.23872
# [48]	validation-rmse:5.23640
# [49]	validation-rmse:5.23608
# [50]	validation-rmse:5.23436
# [51]	validation-rmse:5.23370
# [52]	validation-rmse:5.23321
# [53]	validation-rmse:5.23223
# [54]	validation-rmse:5.23129
# [55]	validation-rmse:5.23016
# [56]	validation-rmse:5.22911
# [57]	validation-rmse:5.22858
# [58]	validation-rmse:5.22819
# [59]	validation-rmse:5.22808
# [60]	validation-rmse:5.22777
# [61]	validation-rmse:5.22728
# [62]	validation-rmse:5.22682
# [63]	validation-rmse:5.22636
# [64]	validation-rmse:5.22589
# [65]	validation-rmse:5.22541
# [66]	validation-rmse:5.22513
# [67]	validation-rmse:5.22504
# [68]	validation-rmse:5.22487
# [69]	validation-rmse:5.22479
# [70]	validation-rmse:5.22475
# [71]	validation-rmse:5.22476
# [72]	validation-rmse:5.22464
# [73]	validation-rmse:5.22441
# [74]	validation-rmse:5.22408
# [75]	validation-rmse:5.22397
# [76]	validation-rmse:5.22369
# [77]	validation-rmse:5.22350
# [78]	validation-rmse:5.22296
# [79]	validation-rmse:5.22280
# [80]	validation-rmse:5.22260
# [81]	validation-rmse:5.22237
# [82]	validation-rmse:5.22216
# [83]	validation-rmse:5.22194
# [84]	validation-rmse:5.22179
# [85]	validation-rmse:5.22177
# [86]	validation-rmse:5.22158
# [87]	validation-rmse:5.22159
# [88]	validation-rmse:5.22158
# [89]	validation-rmse:5.22156
# [90]	validation-rmse:5.22157
# [91]	validation-rmse:5.22131
# [92]	validation-rmse:5.22129
# [93]	validation-rmse:5.22121
# [94]	validation-rmse:5.22120
# [95]	validation-rmse:5.22124
# [96]	validation-rmse:5.22111
# [97]	validation-rmse:5.22112
# [98]	validation-rmse:5.22106
# [99]	validation-rmse:5.22104
# [0]	validation-rmse:9.50345
# [1]	validation-rmse:9.09906
#   2%|▏         | 1/50 [00:21<17:16, 21.16s/trial, best loss: 5.221044635224474]
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [19:06:54] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [2]	validation-rmse:8.80715
# [3]	validation-rmse:8.59567
# [4]	validation-rmse:8.44180
# [5]	validation-rmse:8.33175
# [6]	validation-rmse:8.23966
# [7]	validation-rmse:8.17887
# [8]	validation-rmse:8.12912
# [9]	validation-rmse:8.09004
# [10]	validation-rmse:8.04343
# [11]	validation-rmse:8.01296
# [12]	validation-rmse:7.98865
# [13]	validation-rmse:7.96442
# [14]	validation-rmse:7.94137
# [15]	validation-rmse:7.92387
# [16]	validation-rmse:7.89435
# [17]	validation-rmse:7.88092
# [18]	validation-rmse:7.86515
# [19]	validation-rmse:7.84462
# [20]	validation-rmse:7.83383
# [21]	validation-rmse:7.81523
# [22]	validation-rmse:7.78244
# [23]	validation-rmse:7.76693
# [24]	validation-rmse:7.75507
# [25]	validation-rmse:7.74493
# [26]	validation-rmse:7.73362
# [27]	validation-rmse:7.72533
# [28]	validation-rmse:7.71491
# [29]	validation-rmse:7.70420
# [30]	validation-rmse:7.69328
# [31]	validation-rmse:7.66713
# [32]	validation-rmse:7.65925
# [33]	validation-rmse:7.64034
# [34]	validation-rmse:7.63275
# [35]	validation-rmse:7.62106
# [36]	validation-rmse:7.60544
# [37]	validation-rmse:7.59894
# [38]	validation-rmse:7.59287
# [39]	validation-rmse:7.58226
# [40]	validation-rmse:7.57576
# [41]	validation-rmse:7.57068
# [42]	validation-rmse:7.56283
# [43]	validation-rmse:7.55433
# [44]	validation-rmse:7.54914
# [45]	validation-rmse:7.54286
# [46]	validation-rmse:7.52506
# [47]	validation-rmse:7.50521
# [48]	validation-rmse:7.50006
# [49]	validation-rmse:7.48769
# [50]	validation-rmse:7.48370
# [51]	validation-rmse:7.47875
# [52]	validation-rmse:7.47146
# [53]	validation-rmse:7.46541
# [54]	validation-rmse:7.45181
# [55]	validation-rmse:7.44619
# [56]	validation-rmse:7.44193
# [57]	validation-rmse:7.43475
# [58]	validation-rmse:7.43012
# [59]	validation-rmse:7.42540
# [60]	validation-rmse:7.42091
# [61]	validation-rmse:7.41757
# [62]	validation-rmse:7.41345
# [63]	validation-rmse:7.40815
# [64]	validation-rmse:7.39952
# [65]	validation-rmse:7.39282
# [66]	validation-rmse:7.38920
# [67]	validation-rmse:7.37812
# [68]	validation-rmse:7.37545
# [69]	validation-rmse:7.37034
# [70]	validation-rmse:7.36566
# [71]	validation-rmse:7.36233
# [72]	validation-rmse:7.35040
# [73]	validation-rmse:7.33659
# [74]	validation-rmse:7.33356
# [75]	validation-rmse:7.32866
# [76]	validation-rmse:7.32528
# [77]	validation-rmse:7.32213
# [78]	validation-rmse:7.31992
# [79]	validation-rmse:7.31661
# [80]	validation-rmse:7.31335
# [81]	validation-rmse:7.31062
# [82]	validation-rmse:7.30826
# [83]	validation-rmse:7.30374
# [84]	validation-rmse:7.30031
# [85]	validation-rmse:7.29771
# [86]	validation-rmse:7.29101
# [87]	validation-rmse:7.28505
# [88]	validation-rmse:7.28242
# [89]	validation-rmse:7.27862
# [90]	validation-rmse:7.27630
# [91]	validation-rmse:7.27466
# [92]	validation-rmse:7.26207
# [93]	validation-rmse:7.25937
# [94]	validation-rmse:7.25538
# [95]	validation-rmse:7.25216
# [96]	validation-rmse:7.24744
# [97]	validation-rmse:7.23874
# [98]	validation-rmse:7.23653
# [99]	validation-rmse:7.23276
#   4%|▍         | 2/50 [00:29<10:50, 13.55s/trial, best loss: 5.221044635224474]
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [19:07:02] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:7.37459
# [1]	validation-rmse:6.52010
# [2]	validation-rmse:6.23679
# [3]	validation-rmse:6.05218
# [4]	validation-rmse:5.83820
# [5]	validation-rmse:5.74734
# [6]	validation-rmse:5.70169
# [7]	validation-rmse:5.51593
# [8]	validation-rmse:5.43751
# [9]	validation-rmse:5.40897
# [10]	validation-rmse:5.36159
# [11]	validation-rmse:5.35266
# [12]	validation-rmse:5.34788
# [13]	validation-rmse:5.33125
# [14]	validation-rmse:5.30856
# [15]	validation-rmse:5.30466
# [16]	validation-rmse:5.29889
# [17]	validation-rmse:5.29675
# [18]	validation-rmse:5.29375
# [19]	validation-rmse:5.29257
# [20]	validation-rmse:5.28709
# [21]	validation-rmse:5.28613
# [22]	validation-rmse:5.28557
# [23]	validation-rmse:5.28375
# [24]	validation-rmse:5.28325
# [25]	validation-rmse:5.28260
# [26]	validation-rmse:5.28220
# [27]	validation-rmse:5.28158
# [28]	validation-rmse:5.28103
# [29]	validation-rmse:5.28034
# [30]	validation-rmse:5.27963
# [31]	validation-rmse:5.27916
# [32]	validation-rmse:5.27840
# [33]	validation-rmse:5.27780
# [34]	validation-rmse:5.27682
# [35]	validation-rmse:5.27657
# [36]	validation-rmse:5.27611
# [37]	validation-rmse:5.27490
# [38]	validation-rmse:5.27445
# [39]	validation-rmse:5.27378
# [40]	validation-rmse:5.27322
# [41]	validation-rmse:5.27125
# [42]	validation-rmse:5.27002
# [43]	validation-rmse:5.26892
# [44]	validation-rmse:5.26855
# [45]	validation-rmse:5.26732
# [46]	validation-rmse:5.26708
# [47]	validation-rmse:5.26680
# [48]	validation-rmse:5.26667
# [49]	validation-rmse:5.26637
# [50]	validation-rmse:5.26612
# [51]	validation-rmse:5.26588
# [52]	validation-rmse:5.26570
# [53]	validation-rmse:5.26554
# [54]	validation-rmse:5.26485
# [55]	validation-rmse:5.26476
# [56]	validation-rmse:5.26460
# [57]	validation-rmse:5.26459
# [58]	validation-rmse:5.26424
# [59]	validation-rmse:5.26410
# [60]	validation-rmse:5.26388
# [61]	validation-rmse:5.26369
# [62]	validation-rmse:5.26321
# [63]	validation-rmse:5.26289
# [64]	validation-rmse:5.26223
# [65]	validation-rmse:5.26213
# [66]	validation-rmse:5.26196
# [67]	validation-rmse:5.26205
# [68]	validation-rmse:5.26192
# [69]	validation-rmse:5.26175
# [70]	validation-rmse:5.26167
# [71]	validation-rmse:5.26146
# [72]	validation-rmse:5.26126
# [73]	validation-rmse:5.26120
# [74]	validation-rmse:5.26094
# [75]	validation-rmse:5.26073
# [76]	validation-rmse:5.26044
# [77]	validation-rmse:5.26026
# [78]	validation-rmse:5.26008
# [79]	validation-rmse:5.26000
# [80]	validation-rmse:5.25994
# [81]	validation-rmse:5.25945
# [82]	validation-rmse:5.25945
# [83]	validation-rmse:5.25925
# [84]	validation-rmse:5.25918
# [85]	validation-rmse:5.25896
# [86]	validation-rmse:5.25877
# [87]	validation-rmse:5.25860
# [88]	validation-rmse:5.25848
# [89]	validation-rmse:5.25788
# [90]	validation-rmse:5.25783
# [91]	validation-rmse:5.25756
# [92]	validation-rmse:5.25736
# [93]	validation-rmse:5.25702
# [94]	validation-rmse:5.25683
# [95]	validation-rmse:5.25662
# [96]	validation-rmse:5.25660
# [97]	validation-rmse:5.25646
# [98]	validation-rmse:5.25617
# [99]	validation-rmse:5.25606
#   6%|▌         | 3/50 [00:56<15:19, 19.56s/trial, best loss: 5.221044635224474]
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [19:07:29] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:8.53577
# [1]	validation-rmse:7.60926
# [2]	validation-rmse:6.60798
# [3]	validation-rmse:6.09269
# [4]	validation-rmse:5.93395
# [5]	validation-rmse:5.64831
# [6]	validation-rmse:5.59158
# [7]	validation-rmse:5.46264
# [8]	validation-rmse:5.43903
# [9]	validation-rmse:5.41832
# [10]	validation-rmse:5.35085
# [11]	validation-rmse:5.34244
# [12]	validation-rmse:5.33514
# [13]	validation-rmse:5.29779
# [14]	validation-rmse:5.29403
# [15]	validation-rmse:5.28950
# [16]	validation-rmse:5.28383
# [17]	validation-rmse:5.25849
# [18]	validation-rmse:5.25700
# [19]	validation-rmse:5.24863
# [20]	validation-rmse:5.24680
# [21]	validation-rmse:5.24454
# [22]	validation-rmse:5.23415
# [23]	validation-rmse:5.23146
# [24]	validation-rmse:5.22827
# [25]	validation-rmse:5.22335
# [26]	validation-rmse:5.22263
# [27]	validation-rmse:5.22165
# [28]	validation-rmse:5.21924
# [29]	validation-rmse:5.21396
# [30]	validation-rmse:5.21207
# [31]	validation-rmse:5.21180
# [32]	validation-rmse:5.20906
# [33]	validation-rmse:5.20876
# [34]	validation-rmse:5.20834
# [35]	validation-rmse:5.20815
# [36]	validation-rmse:5.20796
# [37]	validation-rmse:5.20760
# [38]	validation-rmse:5.20748
# [39]	validation-rmse:5.20712
# [40]	validation-rmse:5.20685
# [41]	validation-rmse:5.20671
# [42]	validation-rmse:5.20655
# [43]	validation-rmse:5.20599
# [44]	validation-rmse:5.20581
# [45]	validation-rmse:5.20566
# [46]	validation-rmse:5.20555
# [47]	validation-rmse:5.20506
# [48]	validation-rmse:5.20483
# [49]	validation-rmse:5.20475
# [50]	validation-rmse:5.20459
# [51]	validation-rmse:5.20426
# [52]	validation-rmse:5.20419
# [53]	validation-rmse:5.20414
# [54]	validation-rmse:5.20405
# [55]	validation-rmse:5.20395
# [56]	validation-rmse:5.20388
# [57]	validation-rmse:5.20369
# [58]	validation-rmse:5.20347
# [59]	validation-rmse:5.20339
# [60]	validation-rmse:5.20334
# [61]	validation-rmse:5.20321
# [62]	validation-rmse:5.20312
# [63]	validation-rmse:5.20286
# [64]	validation-rmse:5.20273
# [65]	validation-rmse:5.20264
# [66]	validation-rmse:5.20252
# [67]	validation-rmse:5.20241
# [68]	validation-rmse:5.20241
# [69]	validation-rmse:5.20233
# [70]	validation-rmse:5.20228
# [71]	validation-rmse:5.20219
# [72]	validation-rmse:5.20202
# [73]	validation-rmse:5.20195
# [74]	validation-rmse:5.20183
# [75]	validation-rmse:5.20174
# [76]	validation-rmse:5.20167
# [77]	validation-rmse:5.20158
# [78]	validation-rmse:5.20158
# [79]	validation-rmse:5.20156
# [80]	validation-rmse:5.20150
# [81]	validation-rmse:5.20146
# [82]	validation-rmse:5.20132
# [83]	validation-rmse:5.20128
# [84]	validation-rmse:5.20124
# [85]	validation-rmse:5.20119
# [86]	validation-rmse:5.20093
# [87]	validation-rmse:5.20062
# [88]	validation-rmse:5.20050
# [89]	validation-rmse:5.20043
# [90]	validation-rmse:5.20035
# [91]	validation-rmse:5.20035
# [92]	validation-rmse:5.20029
# [93]	validation-rmse:5.20045
# [94]	validation-rmse:5.20018
# [95]	validation-rmse:5.20026
# [96]	validation-rmse:5.20012
# [97]	validation-rmse:5.19989
# [98]	validation-rmse:5.19981
# [99]	validation-rmse:5.19946
# [0]	validation-rmse:8.52678
#   8%|▊         | 4/50 [01:41<22:45, 29.69s/trial, best loss: 5.1994553723962325]
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [19:08:14] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [1]	validation-rmse:8.00363
# [2]	validation-rmse:7.78060
# [3]	validation-rmse:7.63879
# [4]	validation-rmse:7.46606
# [5]	validation-rmse:7.36703
# [6]	validation-rmse:7.29495
# [7]	validation-rmse:7.22941
# [8]	validation-rmse:7.06864
# [9]	validation-rmse:7.04009
# [10]	validation-rmse:6.99177
# [11]	validation-rmse:6.85545
# [12]	validation-rmse:6.82238
# [13]	validation-rmse:6.80236
# [14]	validation-rmse:6.71701
# [15]	validation-rmse:6.68587
# [16]	validation-rmse:6.66904
# [17]	validation-rmse:6.65548
# [18]	validation-rmse:6.54879
# [19]	validation-rmse:6.53609
# [20]	validation-rmse:6.50794
# [21]	validation-rmse:6.49436
# [22]	validation-rmse:6.47624
# [23]	validation-rmse:6.46237
# [24]	validation-rmse:6.45400
# [25]	validation-rmse:6.44051
# [26]	validation-rmse:6.43419
# [27]	validation-rmse:6.42611
# [28]	validation-rmse:6.34151
# [29]	validation-rmse:6.33031
# [30]	validation-rmse:6.32413
# [31]	validation-rmse:6.27823
# [32]	validation-rmse:6.26158
# [33]	validation-rmse:6.25640
# [34]	validation-rmse:6.22819
# [35]	validation-rmse:6.21314
# [36]	validation-rmse:6.20612
# [37]	validation-rmse:6.20263
# [38]	validation-rmse:6.14523
# [39]	validation-rmse:6.12862
# [40]	validation-rmse:6.11972
# [41]	validation-rmse:6.10538
# [42]	validation-rmse:6.06420
# [43]	validation-rmse:6.05908
# [44]	validation-rmse:6.05318
# [45]	validation-rmse:6.04849
# [46]	validation-rmse:6.04640
# [47]	validation-rmse:6.04142
# [48]	validation-rmse:6.03661
# [49]	validation-rmse:6.03152
# [50]	validation-rmse:6.02658
# [51]	validation-rmse:6.01277
# [52]	validation-rmse:5.99454
# [53]	validation-rmse:5.98004
# [54]	validation-rmse:5.96740
# [55]	validation-rmse:5.94682
# [56]	validation-rmse:5.94393
# [57]	validation-rmse:5.90655
# [58]	validation-rmse:5.90094
# [59]	validation-rmse:5.89229
# [60]	validation-rmse:5.88739
# [61]	validation-rmse:5.87726
# [62]	validation-rmse:5.87311
# [63]	validation-rmse:5.87185
# [64]	validation-rmse:5.86966
# [65]	validation-rmse:5.86764
# [66]	validation-rmse:5.86063
# [67]	validation-rmse:5.84733
# [68]	validation-rmse:5.82661
# [69]	validation-rmse:5.77756
# [70]	validation-rmse:5.72742
# [71]	validation-rmse:5.69515
# [72]	validation-rmse:5.68267
# [73]	validation-rmse:5.64713
# [74]	validation-rmse:5.63425
# [75]	validation-rmse:5.62088
# [76]	validation-rmse:5.60894
# [77]	validation-rmse:5.60671
# [78]	validation-rmse:5.60538
# [79]	validation-rmse:5.60210
# [80]	validation-rmse:5.59639
# [81]	validation-rmse:5.59322
# [82]	validation-rmse:5.59247
# [83]	validation-rmse:5.59183
# [84]	validation-rmse:5.58770
# [85]	validation-rmse:5.58731
# [86]	validation-rmse:5.56210
# [87]	validation-rmse:5.55145
# [88]	validation-rmse:5.53503
# [89]	validation-rmse:5.52066
# [90]	validation-rmse:5.50588
# [91]	validation-rmse:5.50266
# [92]	validation-rmse:5.50162
# [93]	validation-rmse:5.49959
# [94]	validation-rmse:5.49848
# [95]	validation-rmse:5.49680
# [96]	validation-rmse:5.49004
# [97]	validation-rmse:5.48912
# [98]	validation-rmse:5.48860
# [99]	validation-rmse:5.48695
# [0]	validation-rmse:9.49725
#  10%|█         | 5/50 [01:53<17:36, 23.48s/trial, best loss: 5.1994553723962325]
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [19:08:27] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [1]	validation-rmse:9.06768
# [2]	validation-rmse:8.74349
# [3]	validation-rmse:8.50015
# [4]	validation-rmse:8.30196
# [5]	validation-rmse:8.13842
# [6]	validation-rmse:8.01908
# [7]	validation-rmse:7.93273
# [8]	validation-rmse:7.86309
# [9]	validation-rmse:7.80524
# [10]	validation-rmse:7.75707
# [11]	validation-rmse:7.66210
# [12]	validation-rmse:7.62461
# [13]	validation-rmse:7.59509
# [14]	validation-rmse:7.51443
# [15]	validation-rmse:7.48997
# [16]	validation-rmse:7.46702
# [17]	validation-rmse:7.43593
# [18]	validation-rmse:7.41189
# [19]	validation-rmse:7.39296
# [20]	validation-rmse:7.37693
# [21]	validation-rmse:7.30146
# [22]	validation-rmse:7.28872
# [23]	validation-rmse:7.27537
# [24]	validation-rmse:7.21772
# [25]	validation-rmse:7.20428
# [26]	validation-rmse:7.19639
# [27]	validation-rmse:7.18475
# [28]	validation-rmse:7.17775
# [29]	validation-rmse:7.15704
# [30]	validation-rmse:7.14041
# [31]	validation-rmse:7.13137
# [32]	validation-rmse:7.10611
# [33]	validation-rmse:7.04902
# [34]	validation-rmse:7.02906
# [35]	validation-rmse:7.01592
# [36]	validation-rmse:7.00997
# [37]	validation-rmse:7.00337
# [38]	validation-rmse:6.99696
# [39]	validation-rmse:6.96118
# [40]	validation-rmse:6.91327
# [41]	validation-rmse:6.90872
# [42]	validation-rmse:6.90313
# [43]	validation-rmse:6.89535
# [44]	validation-rmse:6.88173
# [45]	validation-rmse:6.87502
# [46]	validation-rmse:6.86937
# [47]	validation-rmse:6.86498
# [48]	validation-rmse:6.86124
# [49]	validation-rmse:6.83185
# [50]	validation-rmse:6.78977
# [51]	validation-rmse:6.78474
# [52]	validation-rmse:6.77989
# [53]	validation-rmse:6.77308
# [54]	validation-rmse:6.76800
# [55]	validation-rmse:6.76372
# [56]	validation-rmse:6.76038
# [57]	validation-rmse:6.74872
# [58]	validation-rmse:6.74584
# [59]	validation-rmse:6.74084
# [60]	validation-rmse:6.71521
# [61]	validation-rmse:6.66908
# [62]	validation-rmse:6.63368
# [63]	validation-rmse:6.63028
# [64]	validation-rmse:6.62760
# [65]	validation-rmse:6.60347
# [66]	validation-rmse:6.59933
# [67]	validation-rmse:6.59650
# [68]	validation-rmse:6.57219
# [69]	validation-rmse:6.56766
# [70]	validation-rmse:6.55204
# [71]	validation-rmse:6.54409
# [72]	validation-rmse:6.54042
# [73]	validation-rmse:6.53608
# [74]	validation-rmse:6.53270
# [75]	validation-rmse:6.52976
# [76]	validation-rmse:6.52677
# [77]	validation-rmse:6.52400
# [78]	validation-rmse:6.52038
# [79]	validation-rmse:6.49778
# [80]	validation-rmse:6.47994
# [81]	validation-rmse:6.47704
# [82]	validation-rmse:6.47499
# [83]	validation-rmse:6.47301
# [84]	validation-rmse:6.46933
# [85]	validation-rmse:6.46752
# [86]	validation-rmse:6.46586
# [87]	validation-rmse:6.46187
# [88]	validation-rmse:6.45907
# [89]	validation-rmse:6.45632
# [90]	validation-rmse:6.45415
# [91]	validation-rmse:6.43210
# [92]	validation-rmse:6.42752
# [93]	validation-rmse:6.42527
# [94]	validation-rmse:6.42209
# [95]	validation-rmse:6.41977
# [96]	validation-rmse:6.41289
# [97]	validation-rmse:6.40990
# [98]	validation-rmse:6.40830
# [99]	validation-rmse:6.38236
# ...
# [98]	validation-rmse:5.22194
# [99]	validation-rmse:5.22184
#  96%|█████████▌| 48/50 [28:28<01:00, 30.42s/trial, best loss: 5.190119363563867]
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [19:35:02] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:9.67791
# [1]	validation-rmse:9.33418
# [2]	validation-rmse:9.03176
# [3]	validation-rmse:8.72879
# [4]	validation-rmse:8.49788
# [5]	validation-rmse:8.22660
# [6]	validation-rmse:8.03923
# [7]	validation-rmse:7.75564
# [8]	validation-rmse:7.50845
# [9]	validation-rmse:7.38129
# [10]	validation-rmse:7.17316
# [11]	validation-rmse:7.07565
# [12]	validation-rmse:6.90754
# [13]	validation-rmse:6.83403
# [14]	validation-rmse:6.76903
# [15]	validation-rmse:6.71094
# [16]	validation-rmse:6.57106
# [17]	validation-rmse:6.52758
# [18]	validation-rmse:6.48925
# [19]	validation-rmse:6.36793
# [20]	validation-rmse:6.33775
# [21]	validation-rmse:6.24341
# [22]	validation-rmse:6.21842
# [23]	validation-rmse:6.13058
# [24]	validation-rmse:6.11042
# [25]	validation-rmse:6.09198
# [26]	validation-rmse:6.07555
# [27]	validation-rmse:6.00116
# [28]	validation-rmse:5.98781
# [29]	validation-rmse:5.92923
# [30]	validation-rmse:5.91748
# [31]	validation-rmse:5.90636
# [32]	validation-rmse:5.89581
# [33]	validation-rmse:5.83713
# [34]	validation-rmse:5.82789
# [35]	validation-rmse:5.77625
# [36]	validation-rmse:5.76820
# [37]	validation-rmse:5.76129
# [38]	validation-rmse:5.75430
# [39]	validation-rmse:5.70906
# [40]	validation-rmse:5.70410
# [41]	validation-rmse:5.69832
# [42]	validation-rmse:5.69149
# [43]	validation-rmse:5.68601
# [44]	validation-rmse:5.64531
# [45]	validation-rmse:5.64135
# [46]	validation-rmse:5.60739
# [47]	validation-rmse:5.60394
# [48]	validation-rmse:5.60041
# [49]	validation-rmse:5.56842
# [50]	validation-rmse:5.56535
# [51]	validation-rmse:5.56072
# [52]	validation-rmse:5.55795
# [53]	validation-rmse:5.55411
# [54]	validation-rmse:5.52925
# [55]	validation-rmse:5.52643
# [56]	validation-rmse:5.52401
# [57]	validation-rmse:5.52036
# [58]	validation-rmse:5.49613
# [59]	validation-rmse:5.49428
# [60]	validation-rmse:5.47392
# [61]	validation-rmse:5.45557
# [62]	validation-rmse:5.45409
# [63]	validation-rmse:5.45210
# [64]	validation-rmse:5.43538
# [65]	validation-rmse:5.43406
# [66]	validation-rmse:5.43185
# [67]	validation-rmse:5.42760
# [68]	validation-rmse:5.42626
# [69]	validation-rmse:5.42474
# [70]	validation-rmse:5.42266
# [71]	validation-rmse:5.42139
# [72]	validation-rmse:5.40759
# [73]	validation-rmse:5.40570
# [74]	validation-rmse:5.40356
# [75]	validation-rmse:5.40222
# [76]	validation-rmse:5.40130
# [77]	validation-rmse:5.38926
# [78]	validation-rmse:5.38799
# [79]	validation-rmse:5.38678
# [80]	validation-rmse:5.38514
# [81]	validation-rmse:5.37300
# [82]	validation-rmse:5.36840
# [83]	validation-rmse:5.36761
# [84]	validation-rmse:5.36618
# [85]	validation-rmse:5.36543
# [86]	validation-rmse:5.36441
# [87]	validation-rmse:5.36313
# [88]	validation-rmse:5.36185
# [89]	validation-rmse:5.36050
# [90]	validation-rmse:5.35954
# [91]	validation-rmse:5.35089
# [92]	validation-rmse:5.35018
# [93]	validation-rmse:5.34762
# [94]	validation-rmse:5.34640
# [95]	validation-rmse:5.34456
# [96]	validation-rmse:5.34361
# [97]	validation-rmse:5.34151
# [98]	validation-rmse:5.34101
# [99]	validation-rmse:5.33996
#  98%|█████████▊| 49/50 [29:05<00:32, 32.31s/trial, best loss: 5.190119363563867]
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [19:35:38] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:7.75988
# [1]	validation-rmse:6.11451
# [2]	validation-rmse:5.83648
# [3]	validation-rmse:5.46542
# [4]	validation-rmse:5.42017
# [5]	validation-rmse:5.32868
# [6]	validation-rmse:5.31280
# [7]	validation-rmse:5.29884
# [8]	validation-rmse:5.26016
# [9]	validation-rmse:5.25629
# [10]	validation-rmse:5.24054
# [11]	validation-rmse:5.23755
# [12]	validation-rmse:5.23193
# [13]	validation-rmse:5.22729
# [14]	validation-rmse:5.21877
# [15]	validation-rmse:5.21790
# [16]	validation-rmse:5.21318
# [17]	validation-rmse:5.21296
# [18]	validation-rmse:5.20836
# [19]	validation-rmse:5.20833
# [20]	validation-rmse:5.20765
# [21]	validation-rmse:5.20582
# [22]	validation-rmse:5.20538
# [23]	validation-rmse:5.20532
# [24]	validation-rmse:5.20513
# [25]	validation-rmse:5.20466
# [26]	validation-rmse:5.20413
# [27]	validation-rmse:5.20387
# [28]	validation-rmse:5.20388
# [29]	validation-rmse:5.20387
# [30]	validation-rmse:5.20341
# [31]	validation-rmse:5.20333
# [32]	validation-rmse:5.20337
# [33]	validation-rmse:5.20335
# [34]	validation-rmse:5.20332
# [35]	validation-rmse:5.20319
# [36]	validation-rmse:5.20320
# [37]	validation-rmse:5.20320
# [38]	validation-rmse:5.20319
# [39]	validation-rmse:5.20321
# [40]	validation-rmse:5.20321
# [41]	validation-rmse:5.20322
# [42]	validation-rmse:5.20324
# [43]	validation-rmse:5.20324
# [44]	validation-rmse:5.20325
# [45]	validation-rmse:5.20322
# [46]	validation-rmse:5.20328
# [47]	validation-rmse:5.20331
# [48]	validation-rmse:5.20332
# [49]	validation-rmse:5.20330
# [50]	validation-rmse:5.20332
# [51]	validation-rmse:5.20333
# [52]	validation-rmse:5.20334
# [53]	validation-rmse:5.20332
# [54]	validation-rmse:5.20336
# [55]	validation-rmse:5.20335
# [56]	validation-rmse:5.20336
# [57]	validation-rmse:5.20337
# [58]	validation-rmse:5.20337
# [59]	validation-rmse:5.20338
# [60]	validation-rmse:5.20339
# [61]	validation-rmse:5.20338
# [62]	validation-rmse:5.20339
# [63]	validation-rmse:5.20340
# [64]	validation-rmse:5.20340
# [65]	validation-rmse:5.20340
# [66]	validation-rmse:5.20340
# [67]	validation-rmse:5.20338
# [68]	validation-rmse:5.20341
# [69]	validation-rmse:5.20340
# [70]	validation-rmse:5.20341
# [71]	validation-rmse:5.20341
# [72]	validation-rmse:5.20340
# [73]	validation-rmse:5.20341
# [74]	validation-rmse:5.20341
# [75]	validation-rmse:5.20342
# [76]	validation-rmse:5.20342
# [77]	validation-rmse:5.20342
# [78]	validation-rmse:5.20342
# [79]	validation-rmse:5.20342
# [80]	validation-rmse:5.20341
# [81]	validation-rmse:5.20342
# [82]	validation-rmse:5.20342
# [83]	validation-rmse:5.20342
# [84]	validation-rmse:5.20341
# 100%|██████████| 50/50 [29:48<00:00, 35.77s/trial, best loss: 5.190119363563867]

# %%
params = {
    'learning_rate': 0.19408972548566633,
    'max_depth': 100,
    'min_child_weight': 1.8824847254189034,
    'objective': 'reg:linear',
    'reg_alpha': 0.13078016502323883,
    'reg_lambda': 0.0001070736826826826,
    'seed': 42
}

mlflow.xgboost.autolog()


booster = xgb.train(
    params=params,
    dtrain=train,
    num_boost_round=100, # was 1000 in the original code
    evals=[(valid, 'validation')],
    early_stopping_rounds=50
)
# Out:
# 2024/06/09 19:56:48 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1e0774bee771491b8f0065a11743b93a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [19:56:50] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:8.98747
# [1]	validation-rmse:8.25230
# [2]	validation-rmse:7.73872
# [3]	validation-rmse:7.03330
# [4]	validation-rmse:6.52753
# [5]	validation-rmse:6.25668
# [6]	validation-rmse:6.11893
# [7]	validation-rmse:5.85720
# [8]	validation-rmse:5.78975
# [9]	validation-rmse:5.62370
# [10]	validation-rmse:5.53003
# [11]	validation-rmse:5.50327
# [12]	validation-rmse:5.43364
# [13]	validation-rmse:5.41354
# [14]	validation-rmse:5.40036
# [15]	validation-rmse:5.38914
# [16]	validation-rmse:5.33734
# [17]	validation-rmse:5.32942
# [18]	validation-rmse:5.29641
# [19]	validation-rmse:5.29214
# [20]	validation-rmse:5.28834
# [21]	validation-rmse:5.28227
# [22]	validation-rmse:5.25889
# [23]	validation-rmse:5.25669
# [24]	validation-rmse:5.25386
# [25]	validation-rmse:5.23956
# [26]	validation-rmse:5.23769
# [27]	validation-rmse:5.23330
# [28]	validation-rmse:5.23002
# [29]	validation-rmse:5.22853
# [30]	validation-rmse:5.22743
# [31]	validation-rmse:5.21863
# [32]	validation-rmse:5.21784
# [33]	validation-rmse:5.21728
# [34]	validation-rmse:5.21163
# [35]	validation-rmse:5.21133
# [36]	validation-rmse:5.20721
# [37]	validation-rmse:5.20690
# [38]	validation-rmse:5.20638
# [39]	validation-rmse:5.20530
# [40]	validation-rmse:5.20388
# [41]	validation-rmse:5.20359
# [42]	validation-rmse:5.20139
# [43]	validation-rmse:5.20109
# [44]	validation-rmse:5.20082
# [45]	validation-rmse:5.19937
# [46]	validation-rmse:5.19923
# [47]	validation-rmse:5.19906
# [48]	validation-rmse:5.19891
# [49]	validation-rmse:5.19866
# [50]	validation-rmse:5.19838
# [51]	validation-rmse:5.19746
# [52]	validation-rmse:5.19593
# [53]	validation-rmse:5.19560
# [54]	validation-rmse:5.19532
# [55]	validation-rmse:5.19516
# [56]	validation-rmse:5.19515
# [57]	validation-rmse:5.19506
# [58]	validation-rmse:5.19491
# [59]	validation-rmse:5.19428
# [60]	validation-rmse:5.19422
# [61]	validation-rmse:5.19414
# [62]	validation-rmse:5.19271
# [63]	validation-rmse:5.19267
# [64]	validation-rmse:5.19265
# [65]	validation-rmse:5.19264
# [66]	validation-rmse:5.19258
# [67]	validation-rmse:5.19244
# [68]	validation-rmse:5.19237
# [69]	validation-rmse:5.19209
# [70]	validation-rmse:5.19209
# [71]	validation-rmse:5.19214
# [72]	validation-rmse:5.19209
# [73]	validation-rmse:5.19204
# [74]	validation-rmse:5.19199
# [75]	validation-rmse:5.19199
# [76]	validation-rmse:5.19191
# [77]	validation-rmse:5.19177
# [78]	validation-rmse:5.19171
# [79]	validation-rmse:5.19170
# [80]	validation-rmse:5.19167
# [81]	validation-rmse:5.19166
# [82]	validation-rmse:5.19159
# [83]	validation-rmse:5.19139
# [84]	validation-rmse:5.19140
# [85]	validation-rmse:5.19137
# [86]	validation-rmse:5.19136
# [87]	validation-rmse:5.19136
# [88]	validation-rmse:5.19131
# [89]	validation-rmse:5.19119
# [90]	validation-rmse:5.19116
# [91]	validation-rmse:5.19118
# [92]	validation-rmse:5.19116
# [93]	validation-rmse:5.19112
# [94]	validation-rmse:5.19110
# [95]	validation-rmse:5.19106
# [96]	validation-rmse:5.19101
# [97]	validation-rmse:5.19104
# [98]	validation-rmse:5.19104
# [99]	validation-rmse:5.19101
# 2024/06/09 19:57:23 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2024/06/09 19:57:23 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [19:57:23] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# 2024/06/09 19:57:24 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2024/06/09 19:57:24 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils."

# %%
mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [19:58:17] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
#   warnings.warn(smsg, UserWarning)

# %%
mlflow.xgboost.autolog(disable=True)

# %%
import pickle

with mlflow.start_run():
    mlflow.set_tag("model", "xgboost")

    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.19408972548566633,
        'max_depth': 100,
        'min_child_weight': 1.8824847254189034,
        'objective': 'reg:linear',
        'reg_alpha': 0.13078016502323883,
        'reg_lambda': 0.0001070736826826826,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=100, # was 1000 in the original code
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)

    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [20:08:20] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:8.98747
# [1]	validation-rmse:8.25230
# [2]	validation-rmse:7.73872
# [3]	validation-rmse:7.03330
# [4]	validation-rmse:6.52753
# [5]	validation-rmse:6.25668
# [6]	validation-rmse:6.11893
# [7]	validation-rmse:5.85720
# [8]	validation-rmse:5.78975
# [9]	validation-rmse:5.62370
# [10]	validation-rmse:5.53003
# [11]	validation-rmse:5.50327
# [12]	validation-rmse:5.43364
# [13]	validation-rmse:5.41354
# [14]	validation-rmse:5.40036
# [15]	validation-rmse:5.38914
# [16]	validation-rmse:5.33734
# [17]	validation-rmse:5.32942
# [18]	validation-rmse:5.29641
# [19]	validation-rmse:5.29214
# [20]	validation-rmse:5.28834
# [21]	validation-rmse:5.28227
# [22]	validation-rmse:5.25889
# [23]	validation-rmse:5.25669
# [24]	validation-rmse:5.25386
# [25]	validation-rmse:5.23956
# [26]	validation-rmse:5.23769
# [27]	validation-rmse:5.23330
# [28]	validation-rmse:5.23002
# [29]	validation-rmse:5.22853
# [30]	validation-rmse:5.22743
# [31]	validation-rmse:5.21863
# [32]	validation-rmse:5.21784
# [33]	validation-rmse:5.21728
# [34]	validation-rmse:5.21163
# [35]	validation-rmse:5.21133
# [36]	validation-rmse:5.20721
# [37]	validation-rmse:5.20690
# [38]	validation-rmse:5.20638
# [39]	validation-rmse:5.20530
# [40]	validation-rmse:5.20388
# [41]	validation-rmse:5.20359
# [42]	validation-rmse:5.20139
# [43]	validation-rmse:5.20109
# [44]	validation-rmse:5.20082
# [45]	validation-rmse:5.19937
# [46]	validation-rmse:5.19923
# [47]	validation-rmse:5.19906
# [48]	validation-rmse:5.19891
# [49]	validation-rmse:5.19866
# [50]	validation-rmse:5.19838
# [51]	validation-rmse:5.19746
# [52]	validation-rmse:5.19593
# [53]	validation-rmse:5.19560
# [54]	validation-rmse:5.19532
# [55]	validation-rmse:5.19516
# [56]	validation-rmse:5.19515
# [57]	validation-rmse:5.19506
# [58]	validation-rmse:5.19491
# [59]	validation-rmse:5.19428
# [60]	validation-rmse:5.19422
# [61]	validation-rmse:5.19414
# [62]	validation-rmse:5.19271
# [63]	validation-rmse:5.19267
# [64]	validation-rmse:5.19265
# [65]	validation-rmse:5.19264
# [66]	validation-rmse:5.19258
# [67]	validation-rmse:5.19244
# [68]	validation-rmse:5.19237
# [69]	validation-rmse:5.19209
# [70]	validation-rmse:5.19209
# [71]	validation-rmse:5.19214
# [72]	validation-rmse:5.19209
# [73]	validation-rmse:5.19204
# [74]	validation-rmse:5.19199
# [75]	validation-rmse:5.19199
# [76]	validation-rmse:5.19191
# [77]	validation-rmse:5.19177
# [78]	validation-rmse:5.19171
# [79]	validation-rmse:5.19170
# [80]	validation-rmse:5.19167
# [81]	validation-rmse:5.19166
# [82]	validation-rmse:5.19159
# [83]	validation-rmse:5.19139
# [84]	validation-rmse:5.19140
# [85]	validation-rmse:5.19137
# [86]	validation-rmse:5.19136
# [87]	validation-rmse:5.19136
# [88]	validation-rmse:5.19131
# [89]	validation-rmse:5.19119
# [90]	validation-rmse:5.19116
# [91]	validation-rmse:5.19118
# [92]	validation-rmse:5.19116
# [93]	validation-rmse:5.19112
# [94]	validation-rmse:5.19110
# [95]	validation-rmse:5.19106
# [96]	validation-rmse:5.19101
# [97]	validation-rmse:5.19104
# [98]	validation-rmse:5.19104
# [99]	validation-rmse:5.19101
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [20:09:12] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
#   warnings.warn(smsg, UserWarning)
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %%
with mlflow.end_run():
    pass
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 with mlflow.end_run():
#       2     pass
#
# AttributeError: __enter__

# %%
logged_model = "runs:/f30801391f284e0aaccfd60cba9a7aec/models_mlflow"

loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [20:11:08] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: f30801391f284e0aaccfd60cba9a7aec

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model)
# Out:
# /Users/kamilakolpashnikova/anaconda3/envs/exp_env/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [20:12:21] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %%
xgboost_model

# %%
y_pred = xgboost_model.predict(valid)

# %%
y_pred
# Out:
# array([ 6.3495045, 44.144955 , 15.8901   , ..., 15.219723 , 11.963885 ,
#        13.507035 ], dtype=float32)

# %%
## creating new experiment

client.create_experiment("some-new-experiments-2")
# Out:
# '2'

# %%
from mlflow.entities import ViewType

runs = client.search_runs(
    experiment_ids="1", 
    filter_string="",
    run_view_type=ViewType.ACTIVE_ONLY,
    max_results=2,
    order_by=["metrics.rmse ASC"]
    )

# %%
for run in runs:
    print(f"run id: {run.info.run_id}, rmse: {run.data.metrics['rmse']:.4f}")
# Out:
# run id: f30801391f284e0aaccfd60cba9a7aec, rmse: 5.1910
# run id: 25efc624f1ac45b68366653dd21dfbe4, rmse: 8.1381

# %%
run_id = "25efc624f1ac45b68366653dd21dfbe4"
model_uri = f"runs:/{run_id}/model"
mlflow.register_model(model_uri, "nyc-taxi-regressor")
# Out:
# Registered model 'nyc-taxi-regressor' already exists. Creating a new version of this model...
# Created version '3' of model 'nyc-taxi-regressor'.
# <ModelVersion: aliases=[], creation_timestamp=1717979370024, current_stage='None', description=None, last_updated_timestamp=1717979370024, name='nyc-taxi-regressor', run_id='25efc624f1ac45b68366653dd21dfbe4', run_link=None, source='/Users/kamilakolpashnikova/Dropbox/Mac/Documents/Jupyter_notebooks/mlops-2024/02-experiment-tracking/mlruns/1/25efc624f1ac45b68366653dd21dfbe4/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=3>

# %%
client.get_registered_model("nyc-taxi-regressor")
# Out:
# <RegisteredModel: aliases={}, creation_timestamp=1717978511344, description='', last_updated_timestamp=1717979370024, latest_versions=[<ModelVersion: aliases=[], creation_timestamp=1717979370024, current_stage='None', description=None, last_updated_timestamp=1717979370024, name='nyc-taxi-regressor', run_id='25efc624f1ac45b68366653dd21dfbe4', run_link=None, source='/Users/kamilakolpashnikova/Dropbox/Mac/Documents/Jupyter_notebooks/mlops-2024/02-experiment-tracking/mlruns/1/25efc624f1ac45b68366653dd21dfbe4/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=3>], name='nyc-taxi-regressor', tags={}>

# %%
latest_versions = client.get_latest_versions("nyc-taxi-regressor")
# Out:
# /var/folders/rx/2p72xf417cn83_mvjvthxc5h0000gn/T/ipykernel_33446/2816607893.py:1: FutureWarning: ``mlflow.tracking.client.MlflowClient.get_latest_versions`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/2.13.2/model-registry.html#migrating-from-stages
#   latest_versions = client.get_latest_versions("nyc-taxi-regressor")

# %%
for version in latest_versions:
    print(f"version: {version.version}, stage: {version.current_stage}")
# Out:
# version: 3, stage: None

# %%
client.transition_model_version_stage(
    name="nyc-taxi-regressor",
    version=1,
    stage="Staging",
    archive_existing_versions=False
)
# Out:
# /var/folders/rx/2p72xf417cn83_mvjvthxc5h0000gn/T/ipykernel_33446/3351308404.py:1: FutureWarning: ``mlflow.tracking.client.MlflowClient.transition_model_version_stage`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/2.13.2/model-registry.html#migrating-from-stages
#   client.transition_model_version_stage(
# <ModelVersion: aliases=[], creation_timestamp=1717978511370, current_stage='Staging', description='', last_updated_timestamp=1717979813694, name='nyc-taxi-regressor', run_id='f30801391f284e0aaccfd60cba9a7aec', run_link='', source='/Users/kamilakolpashnikova/Dropbox/Mac/Documents/Jupyter_notebooks/mlops-2024/02-experiment-tracking/mlruns/1/f30801391f284e0aaccfd60cba9a7aec/artifacts/models_mlflow', status='READY', status_message=None, tags={}, user_id=None, version=1>

# %%
from datetime import datetime

date = datetime.today().date().isoformat()

model_version = 1

client.update_model_version(
    name="nyc-taxi-regressor",
    version=model_version,
    description=f"Model version {model_version} trained on NYC Taxi dataset on {date}"
)
# Out:
# <ModelVersion: aliases=[], creation_timestamp=1717978511370, current_stage='Staging', description='Model version 1 trained on NYC Taxi dataset on 2024-06-09', last_updated_timestamp=1717980052577, name='nyc-taxi-regressor', run_id='f30801391f284e0aaccfd60cba9a7aec', run_link='', source='/Users/kamilakolpashnikova/Dropbox/Mac/Documents/Jupyter_notebooks/mlops-2024/02-experiment-tracking/mlruns/1/f30801391f284e0aaccfd60cba9a7aec/artifacts/models_mlflow', status='READY', status_message=None, tags={}, user_id=None, version=1>

# %% [markdown]
# def preprocess(df, dv):

# %%
def preprocess(df, dv):
    train_dict = df[['PULocationID', 'DOLocationID']].to_dict(orient='records')
    return dv.transform(train_dict)

def test_model(model_uri, X_test, y_test):
    model = mlflow.pyfunc.load_model(model_uri)
    y_pred = model.predict(X_test)
    return {"rmse": root_mean_squared_error(y_test, y_pred)}

# %% [markdown]
# Q1

# %% [markdown]
# Q2 4

# %% [markdown]
# Q3 min_samples_split 2

# %% [markdown]
# Q4 default-artifact-root

# %% [markdown]
# Q5 5.335

# %% [markdown]
# Q6 test_rmse
# 5.567408012462019
